# %%
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Read in the Data

# %%
# load iris dataset
ants = pd.read_csv('all_measurments2020x09.csv')
ants.head()

# Create a Python dataframe
labely = 'HW'
labelx = 'FLI'
labeltarget = 'species'
dataframe = ants

dataframe = dataframe[[labely,labelx,labeltarget]]
unique_values_count = dataframe['species'].nunique()
dataframe.loc[dataframe['species'] == 'zeteki', 'species'] = 0
dataframe.loc[dataframe['species'] == 'fovouros', 'species'] = 1

dataframe.head()
# Out:
#       HW      FLI species
# 0  1.436  62.7437       0
# 1  1.550  58.8387       0
# 2  1.550  58.8387       0
# 3  1.520  60.0000       0
# 4  1.459  60.3838       0

# %% [markdown]
# # Plot the data

# %%
custom_palette = {0: 'red', 1: 'yellow', 2: 'blue'}
sns.scatterplot(y=labely, x=labelx, hue=labeltarget, data=dataframe, palette=custom_palette)
# Out:
# <AxesSubplot: xlabel='FLI', ylabel='HW'>

# %% [markdown]
# # Prepare the Data

# %%
# Separate features (X) and target variable (y)
X = dataframe.drop(labeltarget, axis=1)
y = dataframe[labeltarget]
X.head()

# Split the dataset into training, testing, and validation sets
# NOTE: DO NOT TOUCH THE VALIDATION SCRIPT 
# NOTE: DO NOT CHANGE THESE RANDOM_STATE VARIABLES
X_train, X_test_val, y_train, y_test_val = train_test_split(X, y, test_size=0.4, random_state=40)
X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.2, random_state=40)

# Scale
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_scaled = scaler.transform(X)

# %% [markdown]
# # Softmax Regression

# %%
# Initialize and fit the logistic regression model
logreg = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)
logreg.fit(X_train_scaled, y_train)

# Predictions on the test set
y_pred = logreg.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 3
#       1 # Initialize and fit the logistic regression model
#       2 logreg = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)
# ----> 3 logreg.fit(X_train_scaled, y_train)
#       5 # Predictions on the test set
#       6 y_pred = logreg.predict(X_test_scaled)
#
# File /usr/local/Caskroom/miniconda/base/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1204, in LogisticRegression.fit(self, X, y, sample_weight)
#    1194     _dtype = [np.float64, np.float32]
#    1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    (...)
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
# -> 1204 check_classification_targets(y)
#    1205 self.classes_ = np.unique(y)
# ...

# %% [markdown]
# # Plot the Decision Boundaries

# %%
# Get decision boundaries
h = 0.02  # Step size in the mesh
x_min, x_max = X_scaled[:, 0].min() - 1, X_scaled[:, 0].max() + 1
y_min, y_max = X_scaled[:, 1].min() - 1, X_scaled[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Get predictions for each point in the mesh
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


# Plot the scatter plot
scatter = sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:,1], hue=y, palette=custom_palette)

# Match contour colors with scatter plot colors
contour = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.2)

# Add legend for the scatter plot
scatter.legend()

plt.title('Softmax Regression Decision Boundaries')
plt.xlabel(labelx)
plt.ylabel(labely)
plt.show()

# %% [markdown]
# # Fit Support Vector Machine

# %%
# Initialize and fit the SVM model
svm_model = SVC(kernel='rbf', C=1, degree=5)  # You can adjust the kernel and C parameter as needed
svm_model.fit(X_train_scaled, y_train)

# Predictions on the test set
y_pred_svm = svm_model.predict(X_test_scaled)

# Evaluate the SVM model
# Evaluate the model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
conf_matrix_svm = confusion_matrix(y_test, y_pred_svm)

print(f'Accuracy: {accuracy_svm:.2f}')
print('Confusion Matrix:')
print(conf_matrix_svm)
# Out:
# Accuracy: 0.99
# Confusion Matrix:
# [[33  1]
#  [ 0 52]]

# %% [markdown]
# # Plot the Decision Boundaries

# %%
# Get predictions for each point in the mesh
Z_svm = svm_model.predict(np.c_[xx.ravel(), yy.ravel()])
Z_svm = Z_svm.reshape(xx.shape)

# Plot the scatter plot
scatter = sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:,1], hue=y, palette=custom_palette)

# Match contour colors with scatter plot colors for SVM
contour_svm = plt.contourf(xx, yy, Z_svm, cmap=plt.cm.RdYlBu, alpha=0.2)

# Add legend for the scatter plot
scatter.legend()

plt.title('SVM Decision Boundaries')
plt.xlabel(labelx)
plt.ylabel(labely)
plt.show()
